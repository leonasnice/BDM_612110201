# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Title 1
# ## Title2
# ### Title 3
# Description

# %% [markdown]
# ## Basic Python
# ### 1. User input and output

# %%
print('Hello World')  ## จะใช้ "" หรือ '' ครอบก็ได้

# %%
name = "Plenoi"
print("Hello "+name+"! "+name+"!")

# %%
country = input("Where are you from = ")  ## รับค่าใส่ใน country

# %%
print("I am from " + country)

# %% [markdown]
# ### 2. Variables

# %%
goal = "Being Data Scientist !!"
print(goal)

# %%
pi = 3.14
print(pi)

# %%
print("The pi is equal to " +str(pi))
print("The pi is equal to %.2f" %(pi))

# %% [markdown]
# ### 3. Arithmetic Operations

# %%
5 + 2 - (4*3)  ## คิดในวงเล็บก่อน

# %%
5 // 2  ## หารไม่เอาเศษ

# %%
5 / 2   ## หารเอาเศษ

# %%
7 % 5   ## แสดงค่าที่เหลือจากการหาร

# %%
5 ** 2   ## ยกกำลัง

# %%
f = 4
g = 4
print(f+g)

# %% [markdown]
# ### 4. Strings

# %%
greeting = "Hello"
name = ' World'
print(greeting + name)   ## string + กัน

# %%
nice = "saharat"   ## เช็ค h ใน nice
"h" in (nice)

# %%
name = "Plenoi"
age = 20
print("Hello my name is "+name+" and my age is "+str(age))  ## แสดงค่าแบบนี้ง่ายสุด

# %%
print('"Hello" "World" "PyThon"')

# %%
my_string = "Hello World"              ## เทนที่ World ด้วย Nice
my_string.replace("World","Nice")

# %%
my_string.lower()  ## เปลี่ยนเป็นพิมพ์เล็ก

# %%
my_string.find("World")  ## หาตำแหน่งคำว่า World

# %%
my_string.capitalize()  ## เปลี่ยนตัวแรกเป็นพิมพ์ใหญ่

# %%
my_string.replace("World","Nixe")  ## เปลี่ยนคำว่า World เป็น Nixe

# %%
my_string.rstrip()  ## ตัด /n ออกเวลา user กด enter ใส่เข้ามา

# %%
my_string[2]  ## แสดงตำแหน่งที่ 2

# %%
my_string.join("ABCD")  ## ใส่ตัวแปล my_string แทรกเข้าไปใน ABCD

# %% [markdown]
# ### 5. Lists

# %%
L = [1,2,3,"Hello","World"]
L.append("Plenoi")               ## append เพิ่มข้อมูลไปใน list
L

# %%
L.remove(3)   ## ลบข้อมูลที่เป็นเลข 3 ออก
L

# %%
L.pop(3)   ## เอาข้อมูลตำแหน่งที่ 3 ออก
L

# %%
L = [[1,2,3],
     [4,5,6],
     [7,8,9]]
L

# %%
L.reverse()    ## ย้อนกลับ list จากมากไปน้อย
L

# %%
L.sort()   ## เรียงจากน้อยไปมาก
L

# %%
[1,2,3] in L  ## หา 2 ในตัวแปล L

# %%
L = []
L.append(1)
L.append(2)
L.append(3)
L

# %%
L = L + [4,5]   ## เพิ่มข้อมูลโดยการ +

L

# %%
len(L)  ## นับจำนวนข้อมูลที่มีในตัวแปล L

# %% [markdown]
# ### 6. Dictionnary

# %%
course = {
  "954340": "Enterprise Database",
  "954471": "Business Data Mining",
  "954472": "Business Data Visualization"
}
print(course)          ## dic เป็นการใส่ข้อมูลแบบเป็น key และ values ต้องควบคู่กัน

# %%
course["954471"]  ## แสดง values ของ key ที่หา

# %%
course["954499"] = "Independent Study"  ## เพิ่มข้อมูลเข้าไปใน Dictionary
course

# %%
course.keys()  ## แสดง keys ทั้งหมดใน course

# %%
course.values()  ## แสดง values ทั้งหมดใน course

# %%
list(course.values())  ## เก็บ values ของ course เป็น list

# %%
sorted(course)  ## เรียง keys ของ course จากน้อยไปมาก

# %%
sorted(course.values())  ## เรียง values ของ course จากน้อยไปมาก

# %%
"954472" in course

# %%
"Business Data Mining" in course.values()

# %%
len(course)  ## จน.ชุดข้อมูลใน course

# %%
course = {}     ## reset ค่าใน course แล้ว update ค่าเพิ่มเข้าไปใหม่
course.update({"954471":"Business Data Mining"})
course.update({"954472":"Business Data Visualization"})
course

# %% [markdown]
# ## 7. Conditional Statements

# %%
x = 6                   ## ห้ามลืม : หลัง if ด้วย
if x > 5:
    print("X > 5")

# %%
x = 2
if x > 5:
    print("X > 5")
else:
    print("X <= 5")

# %%
x = 5                ## ใช้ elif แทน else if
if x > 5:
    print("X > 5")
elif x < 5:
    print("X < 5")
else:
    print("X = 5")

# %%
L = ["Pladook", "Jan", "Om-Cha", "Here"]
if "Here" in L:
    print("Here in L")

# %%
if "Good" not in L:
    print("Good not in L")

# %%
if "Good" in L and "Here" in L:
    print("In")
else:
    print("Not in")

# %%
if "Good" in L or "Here" in L:
    print("In")
else:
    print("Not in")

# %% [markdown]
# ## 8. Loop

# %%
for i in range(0,10):      ## เรียงเลขจาก 0-9
    print(i)

# %%
for i in range(0,10,2):     ## เรียงเลขจาก 0-9 โดยเพิ่มทีละ 2
    print(i)

# %%
L = ["A", "B", "C"]
for item in L:
    print(item)

# %%
D = {"954471":"BDM","954472":"BDV","954340":"EDB"}   ## D ในที่นี้คือ Dictionary
for key,value in D.items():
    print(key+" "+value)

# %%
for key in sorted(D):       ## แสดงข้อมูลเรียงจากน้อยไปมากโอยอิงจาก keys เป็นหลัก
    print(key+" "+D[key])

# %%
i = 0
while i < 5:
    print(i)
    i+=1

# %% [markdown]
# ## 9. List Comprehension

# %%
L = [i for i in range(0,10)]
L

# %%
Letter = [ letter for letter in 'Plenoi' ]
Letter

# %%
sum(i for i in range(0,10))    ## บวก 0-9

# %%
sum(i for i in range(0,10) if i <= 5)  ## บวกเลข 0-9 โดยที่ ค่า i ต้องน้อยกว่าหรือเท่ากับ5 หรือก็คือการเอา 1-5 บวกกัน แบบเก่า

# %% [markdown]
# ## 10. Function

# %%
def power(x, y):     ##  แสดงการยกำลัง
    return x**y

power(2,10)

# %%
def concat(A, B):
    A = A + " First"
    B = B + " Second"
    C = A + " " + B + " Combined"
    return A,B,C

x, y, z = concat("Pladook","Here")
[x] + [y] + [z]

# %% [markdown]
# ## Ex6

# %%
sorted(course.values())

# %% [markdown]
# ## Ex5

# %%
L.sort(reverse=True)  ## เรียงข้อมูลจากมากไปน้อย
L

# %% [markdown]
# ## Ex4

# %%
print("['Hello','World']")

# %% [markdown]
# ## Ex3

# %%
a = input("What is your A = ")      ## ค่าที่รับมาจะเป็น string ซึ่ง str ไม่สามารถนำมาคำนวณได้จึงต้องแปลงเป็น int ก่อน
b = input("What is your B = ")
c = int(a) + int(b)
print(c)

# %% [markdown]
# ## Ex2

# %%
pi = 3.14                              ## int ไม่สามารถ + กับ str ได้จึงต้องแปลง int เป็น str       
print(pi)
print("The pi is equal to " +str(pi))

# %% [markdown]
# ## Ex1

# %%
age = input("What is your age = ")
tenyears_age = int(age) + 10
print(tenyears_age)

# %% [markdown]
# # Assignment

# %% [markdown]
# ### 1. Write a Python program to construct the following pattern, using a nested for loop.

# %%
n = input("n : ")
for i in range(0,int(n)+1):
    print("*"*i)

# %%
for i in range(10):
    print("x" + "x"*i)

# %% [markdown]
# ### 2. Write a Python program to count the number of even and odd numbers from a series of numbers.

# %%
number = input("")
eo = number.split(",")
even,odd = 0,0
for num in eo: 
    if int(num) % 2 == 0: 
        even += 1
    else: 
        odd += 1       
print("Even numbers in the list: ", even) 
print("Odd numbers in the list: ", odd)

# %%
L = [i for i in range(1,10)]

odd = [x for x in L if x % 2 == 1] 
even = len(odd) 

print("Number of even numbers: ", even) 
print("Number of odd numbers : ", len(L) - even)
